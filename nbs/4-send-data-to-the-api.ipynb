# %%
import requests

# %%
data = {"page": "/test+"}

# %%
import json

json.dumps(data)
# Out:
# '{"page": "/test+"}'

# %%
path = "/api/events/"
base_url = "http://localhost:8002"
create_endpoint = f"{base_url}{path}"

response = requests.post(create_endpoint, json={"page": "/test+", "description": '123'}) # HTTP POST
print(response.headers)
print('ok', response.ok)
if response.ok:
  data = response.json()
  print(data, type(data), data.get('items'))
else:
  print(response.text)
# Out:
# {'date': 'Mon, 20 Apr 2026 08:48:41 GMT', 'server': 'uvicorn', 'content-length': '128', 'content-type': 'application/json'}
# ok False
# {"detail":[{"type":"missing","loc":["body","session_id"],"msg":"Field required","input":{"page":"/test+","description":"123"}}]}

# %%
detail_path = "/api/events/1/"
detail_endpoint = f"{base_url}{detail_path}"
headers = {
  "Content-Type": "application/json"
}
response = requests.put(detail_endpoint, json={"description": "Inline test"}) # HTTP PUT
print(response.headers)
print('ok', response.status_code)
if response.ok:
  data = response.json()
  print(data, type(data), data.get('items'))
else:
  print(response.text)
# Out:
# {'date': 'Mon, 20 Apr 2026 08:48:44 GMT', 'server': 'uvicorn', 'allow': 'GET', 'content-length': '31', 'content-type': 'application/json'}
# ok 405
# {"detail":"Method Not Allowed"}

# %%
import random
event_count = 200

pages = ['/about', '/contact', '/pages', '/pricing']


for i in range(event_count):
  page = random.choice(pages)
  response = requests.post(create_endpoint, json={"page": page})
if response.ok:
  data = response.json()
  print(data, type(data), data.get('items'))
else:
  print(response.text)
# Out:
# {"detail":[{"type":"missing","loc":["body","session_id"],"msg":"Field required","input":{"page":"/pages"}}]}

# %%
# %pip install faker
# Out:
# Requirement already satisfied: faker in c:\Users\Administrador\Desktop\All Projects\Analystics - api\venv\Lib\site-packages (40.15.0)
# Requirement already satisfied: tzdata in c:\Users\Administrador\Desktop\All Projects\Analystics - api\venv\Lib\site-packages (from faker) (2026.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from faker import Faker
import random
events = 500
pages = [
  "/", "/about", "/pricing", "/contact",
  "/blog", "/products", "/login", "/singup",
  "/dashboard", "/settings"
]
fake = Faker()
session_ids = [fake.uuid4() for _ in range(20)]
path = "/api/events/"
base_url = "http://localhost:8002"
create_endpoint = f"{base_url}{path}"
referrers = [
  "https://google.com",
  "https://facebook.com",
  "https://twitter.com",
  "https://linkedin.com",
  "",
  "https://github.com"
]

for i in range(events):
    user_agent = random.choice([
        fake.chrome,
        fake.firefox,
        fake.safari,
        fake.opera,
        fake.user_agent
    ])()

    payload = dict(
        page=random.choice(pages),
        user_agent=user_agent,
        ip_address=fake.ipv4(),
        referrer=random.choice(referrers),
        session_id=random.choice(session_ids),
        duration=str(random.randint(50, 5000)) # Transformado em String
    )

    response = requests.post(create_endpoint, json=payload)
    
    if response.ok:
        print(f"Evento {i} enviado com sucesso!")
    else:
        print(f"Erro no evento {i}: {response.text}")
# Out:
# Evento 0 enviado com sucesso!
# Evento 1 enviado com sucesso!
# Evento 2 enviado com sucesso!
# Evento 3 enviado com sucesso!
# Evento 4 enviado com sucesso!
# Evento 5 enviado com sucesso!
# Evento 6 enviado com sucesso!
# Evento 7 enviado com sucesso!
# Evento 8 enviado com sucesso!
# Evento 9 enviado com sucesso!
# Evento 10 enviado com sucesso!
# Evento 11 enviado com sucesso!
# Evento 12 enviado com sucesso!
# Evento 13 enviado com sucesso!
# Evento 14 enviado com sucesso!
# Evento 15 enviado com sucesso!
# Evento 16 enviado com sucesso!
# Evento 17 enviado com sucesso!
# Evento 18 enviado com sucesso!
# Evento 19 enviado com sucesso!
# Evento 20 enviado com sucesso!
# Evento 21 enviado com sucesso!
# Evento 22 enviado com sucesso!
# Evento 23 enviado com sucesso!
# Evento 24 enviado com sucesso!
# Evento 25 enviado com sucesso!
# Evento 26 enviado com sucesso!
# Evento 27 enviado com sucesso!
# Evento 28 enviado com sucesso!
# Evento 29 enviado com sucesso!
# Evento 30 enviado com sucesso!
# Evento 31 enviado com sucesso!
# Evento 32 enviado com sucesso!
# Evento 33 enviado com sucesso!
# Evento 34 enviado com sucesso!
# Evento 35 enviado com sucesso!
# Evento 36 enviado com sucesso!
# Evento 37 enviado com sucesso!
# Evento 38 enviado com sucesso!
# Evento 39 enviado com sucesso!
# Evento 40 enviado com sucesso!
# Evento 41 enviado com sucesso!
# Evento 42 enviado com sucesso!
# Evento 43 enviado com sucesso!
# Evento 44 enviado com sucesso!
# Evento 45 enviado com sucesso!
# Evento 46 enviado com sucesso!
# Evento 47 enviado com sucesso!
# Evento 48 enviado com sucesso!
# Evento 49 enviado com sucesso!
# Evento 50 enviado com sucesso!
# Evento 51 enviado com sucesso!
# Evento 52 enviado com sucesso!
# Evento 53 enviado com sucesso!
# Evento 54 enviado com sucesso!
# Evento 55 enviado com sucesso!
# Evento 56 enviado com sucesso!
# Evento 57 enviado com sucesso!
# Evento 58 enviado com sucesso!
# Evento 59 enviado com sucesso!
# Evento 60 enviado com sucesso!
# Evento 61 enviado com sucesso!
# Evento 62 enviado com sucesso!
# Evento 63 enviado com sucesso!
# Evento 64 enviado com sucesso!
# Evento 65 enviado com sucesso!
# Evento 66 enviado com sucesso!
# Evento 67 enviado com sucesso!
# Evento 68 enviado com sucesso!
# Evento 69 enviado com sucesso!
# Evento 70 enviado com sucesso!
# Evento 71 enviado com sucesso!
# Evento 72 enviado com sucesso!
# Evento 73 enviado com sucesso!
# Evento 74 enviado com sucesso!
# Evento 75 enviado com sucesso!
# Evento 76 enviado com sucesso!
# Evento 77 enviado com sucesso!
# Evento 78 enviado com sucesso!
# Evento 79 enviado com sucesso!
# Evento 80 enviado com sucesso!
# Evento 81 enviado com sucesso!
# Evento 82 enviado com sucesso!
# Evento 83 enviado com sucesso!
# Evento 84 enviado com sucesso!
# Evento 85 enviado com sucesso!
# Evento 86 enviado com sucesso!
# Evento 87 enviado com sucesso!
# Evento 88 enviado com sucesso!
# Evento 89 enviado com sucesso!
# Evento 90 enviado com sucesso!
# Evento 91 enviado com sucesso!
# Evento 92 enviado com sucesso!
# Evento 93 enviado com sucesso!
# Evento 94 enviado com sucesso!
# Evento 95 enviado com sucesso!
# Evento 96 enviado com sucesso!
# Evento 97 enviado com sucesso!
# Evento 98 enviado com sucesso!
# Evento 99 enviado com sucesso!
# Evento 100 enviado com sucesso!
# Evento 101 enviado com sucesso!
# Evento 102 enviado com sucesso!
# Evento 103 enviado com sucesso!
# Evento 104 enviado com sucesso!
# Evento 105 enviado com sucesso!
# Evento 106 enviado com sucesso!
# Evento 107 enviado com sucesso!
# Evento 108 enviado com sucesso!
# Evento 109 enviado com sucesso!
# Evento 110 enviado com sucesso!
# Evento 111 enviado com sucesso!
# Evento 112 enviado com sucesso!
# Evento 113 enviado com sucesso!
# Evento 114 enviado com sucesso!
# Evento 115 enviado com sucesso!
# Evento 116 enviado com sucesso!
# Evento 117 enviado com sucesso!
# Evento 118 enviado com sucesso!
# Evento 119 enviado com sucesso!
# Evento 120 enviado com sucesso!
# Evento 121 enviado com sucesso!
# Evento 122 enviado com sucesso!
# Evento 123 enviado com sucesso!
# Evento 124 enviado com sucesso!
# Evento 125 enviado com sucesso!
# Evento 126 enviado com sucesso!
# Evento 127 enviado com sucesso!
# Evento 128 enviado com sucesso!
# Evento 129 enviado com sucesso!
# Evento 130 enviado com sucesso!
# Evento 131 enviado com sucesso!
# Evento 132 enviado com sucesso!
# Evento 133 enviado com sucesso!
# Evento 134 enviado com sucesso!
# Evento 135 enviado com sucesso!
# Evento 136 enviado com sucesso!
# Evento 137 enviado com sucesso!
# Evento 138 enviado com sucesso!
# Evento 139 enviado com sucesso!
# Evento 140 enviado com sucesso!
# Evento 141 enviado com sucesso!
# Evento 142 enviado com sucesso!
# Evento 143 enviado com sucesso!
# Evento 144 enviado com sucesso!
# Evento 145 enviado com sucesso!
# Evento 146 enviado com sucesso!
# Evento 147 enviado com sucesso!
# Evento 148 enviado com sucesso!
# Evento 149 enviado com sucesso!
# Evento 150 enviado com sucesso!
# Evento 151 enviado com sucesso!
# Evento 152 enviado com sucesso!
# Evento 153 enviado com sucesso!
# Evento 154 enviado com sucesso!
# Evento 155 enviado com sucesso!
# Evento 156 enviado com sucesso!
# Evento 157 enviado com sucesso!
# Evento 158 enviado com sucesso!
# Evento 159 enviado com sucesso!
# Evento 160 enviado com sucesso!
# Evento 161 enviado com sucesso!
# Evento 162 enviado com sucesso!
# Evento 163 enviado com sucesso!
# Evento 164 enviado com sucesso!
# Evento 165 enviado com sucesso!
# Evento 166 enviado com sucesso!
# Evento 167 enviado com sucesso!
# Evento 168 enviado com sucesso!
# Evento 169 enviado com sucesso!
# Evento 170 enviado com sucesso!
# Evento 171 enviado com sucesso!
# Evento 172 enviado com sucesso!
# Evento 173 enviado com sucesso!
# Evento 174 enviado com sucesso!
# Evento 175 enviado com sucesso!
# Evento 176 enviado com sucesso!
# Evento 177 enviado com sucesso!
# Evento 178 enviado com sucesso!
# Evento 179 enviado com sucesso!
# Evento 180 enviado com sucesso!
# Evento 181 enviado com sucesso!
# Evento 182 enviado com sucesso!
# Evento 183 enviado com sucesso!
# Evento 184 enviado com sucesso!
# Evento 185 enviado com sucesso!
# Evento 186 enviado com sucesso!
# Evento 187 enviado com sucesso!
# Evento 188 enviado com sucesso!
# Evento 189 enviado com sucesso!
# Evento 190 enviado com sucesso!
# Evento 191 enviado com sucesso!
# Evento 192 enviado com sucesso!
# Evento 193 enviado com sucesso!
# Evento 194 enviado com sucesso!
# Evento 195 enviado com sucesso!
# Evento 196 enviado com sucesso!
# Evento 197 enviado com sucesso!
# Evento 198 enviado com sucesso!
# Evento 199 enviado com sucesso!
# Evento 200 enviado com sucesso!
# Evento 201 enviado com sucesso!
# Evento 202 enviado com sucesso!
# Evento 203 enviado com sucesso!
# Evento 204 enviado com sucesso!
# Evento 205 enviado com sucesso!
# Evento 206 enviado com sucesso!
# Evento 207 enviado com sucesso!
# Evento 208 enviado com sucesso!
# Evento 209 enviado com sucesso!
# Evento 210 enviado com sucesso!
# Evento 211 enviado com sucesso!
# Evento 212 enviado com sucesso!
# Evento 213 enviado com sucesso!
# Evento 214 enviado com sucesso!
# Evento 215 enviado com sucesso!
# Evento 216 enviado com sucesso!
# Evento 217 enviado com sucesso!
# Evento 218 enviado com sucesso!
# Evento 219 enviado com sucesso!
# Evento 220 enviado com sucesso!
# Evento 221 enviado com sucesso!
# Evento 222 enviado com sucesso!
# Evento 223 enviado com sucesso!
# Evento 224 enviado com sucesso!
# Evento 225 enviado com sucesso!
# Evento 226 enviado com sucesso!
# Evento 227 enviado com sucesso!
# Evento 228 enviado com sucesso!
# Evento 229 enviado com sucesso!
# Evento 230 enviado com sucesso!
# Evento 231 enviado com sucesso!
# Evento 232 enviado com sucesso!
# Evento 233 enviado com sucesso!
# Evento 234 enviado com sucesso!
# Evento 235 enviado com sucesso!
# Evento 236 enviado com sucesso!
# Evento 237 enviado com sucesso!
# Evento 238 enviado com sucesso!
# Evento 239 enviado com sucesso!
# Evento 240 enviado com sucesso!
# Evento 241 enviado com sucesso!
# Evento 242 enviado com sucesso!
# Evento 243 enviado com sucesso!
# Evento 244 enviado com sucesso!
# Evento 245 enviado com sucesso!
# Evento 246 enviado com sucesso!
# Evento 247 enviado com sucesso!
# Evento 248 enviado com sucesso!
# Evento 249 enviado com sucesso!
# Evento 250 enviado com sucesso!
# Evento 251 enviado com sucesso!
# Evento 252 enviado com sucesso!
# Evento 253 enviado com sucesso!
# Evento 254 enviado com sucesso!
# Evento 255 enviado com sucesso!
# Evento 256 enviado com sucesso!
# Evento 257 enviado com sucesso!
# Evento 258 enviado com sucesso!
# Evento 259 enviado com sucesso!
# Evento 260 enviado com sucesso!
# Evento 261 enviado com sucesso!
# Evento 262 enviado com sucesso!
# Evento 263 enviado com sucesso!
# Evento 264 enviado com sucesso!
# Evento 265 enviado com sucesso!
# Evento 266 enviado com sucesso!
# Evento 267 enviado com sucesso!
# Evento 268 enviado com sucesso!
# Evento 269 enviado com sucesso!
# Evento 270 enviado com sucesso!
# Evento 271 enviado com sucesso!
# Evento 272 enviado com sucesso!
# Evento 273 enviado com sucesso!
# Evento 274 enviado com sucesso!
# Evento 275 enviado com sucesso!
# Evento 276 enviado com sucesso!
# Evento 277 enviado com sucesso!
# Evento 278 enviado com sucesso!
# Evento 279 enviado com sucesso!
# Evento 280 enviado com sucesso!
# Evento 281 enviado com sucesso!
# Evento 282 enviado com sucesso!
# Evento 283 enviado com sucesso!
# Evento 284 enviado com sucesso!
# Evento 285 enviado com sucesso!
# Evento 286 enviado com sucesso!
# Evento 287 enviado com sucesso!
# Evento 288 enviado com sucesso!
# Evento 289 enviado com sucesso!
# Evento 290 enviado com sucesso!
# Evento 291 enviado com sucesso!
# Evento 292 enviado com sucesso!
# Evento 293 enviado com sucesso!
# Evento 294 enviado com sucesso!
# Evento 295 enviado com sucesso!
# Evento 296 enviado com sucesso!
# Evento 297 enviado com sucesso!
# Evento 298 enviado com sucesso!
# Evento 299 enviado com sucesso!
# Evento 300 enviado com sucesso!
# Evento 301 enviado com sucesso!
# Evento 302 enviado com sucesso!
# Evento 303 enviado com sucesso!
# Evento 304 enviado com sucesso!
# Evento 305 enviado com sucesso!
# Evento 306 enviado com sucesso!
# Evento 307 enviado com sucesso!
# Evento 308 enviado com sucesso!
# Evento 309 enviado com sucesso!
# Evento 310 enviado com sucesso!
# Evento 311 enviado com sucesso!
# Evento 312 enviado com sucesso!
# Evento 313 enviado com sucesso!
# Evento 314 enviado com sucesso!
# Evento 315 enviado com sucesso!
# Evento 316 enviado com sucesso!
# Evento 317 enviado com sucesso!
# Evento 318 enviado com sucesso!
# Evento 319 enviado com sucesso!
# Evento 320 enviado com sucesso!
# Evento 321 enviado com sucesso!
# Evento 322 enviado com sucesso!
# Evento 323 enviado com sucesso!
# Evento 324 enviado com sucesso!
# Evento 325 enviado com sucesso!
# Evento 326 enviado com sucesso!
# Evento 327 enviado com sucesso!
# Evento 328 enviado com sucesso!
# Evento 329 enviado com sucesso!
# Evento 330 enviado com sucesso!
# Evento 331 enviado com sucesso!
# Evento 332 enviado com sucesso!
# Evento 333 enviado com sucesso!
# Evento 334 enviado com sucesso!
# Evento 335 enviado com sucesso!
# Evento 336 enviado com sucesso!
# Evento 337 enviado com sucesso!
# Evento 338 enviado com sucesso!
# Evento 339 enviado com sucesso!
# Evento 340 enviado com sucesso!
# Evento 341 enviado com sucesso!
# Evento 342 enviado com sucesso!
# Evento 343 enviado com sucesso!
# Evento 344 enviado com sucesso!
# Evento 345 enviado com sucesso!
# Evento 346 enviado com sucesso!
# Evento 347 enviado com sucesso!
# Evento 348 enviado com sucesso!
# Evento 349 enviado com sucesso!
# Evento 350 enviado com sucesso!
# Evento 351 enviado com sucesso!
# Evento 352 enviado com sucesso!
# Evento 353 enviado com sucesso!
# Evento 354 enviado com sucesso!
# Evento 355 enviado com sucesso!
# Evento 356 enviado com sucesso!
# Evento 357 enviado com sucesso!
# Evento 358 enviado com sucesso!
# Evento 359 enviado com sucesso!
# Evento 360 enviado com sucesso!
# Evento 361 enviado com sucesso!
# Evento 362 enviado com sucesso!
# Evento 363 enviado com sucesso!
# Evento 364 enviado com sucesso!
# Evento 365 enviado com sucesso!
# Evento 366 enviado com sucesso!
# Evento 367 enviado com sucesso!
# Evento 368 enviado com sucesso!
# Evento 369 enviado com sucesso!
# Evento 370 enviado com sucesso!
# Evento 371 enviado com sucesso!
# Evento 372 enviado com sucesso!
# Evento 373 enviado com sucesso!
# Evento 374 enviado com sucesso!
# Evento 375 enviado com sucesso!
# Evento 376 enviado com sucesso!
# Evento 377 enviado com sucesso!
# Evento 378 enviado com sucesso!
# Evento 379 enviado com sucesso!
# Evento 380 enviado com sucesso!
# Evento 381 enviado com sucesso!
# Evento 382 enviado com sucesso!
# Evento 383 enviado com sucesso!
# Evento 384 enviado com sucesso!
# Evento 385 enviado com sucesso!
# Evento 386 enviado com sucesso!
# Evento 387 enviado com sucesso!
# Evento 388 enviado com sucesso!
# Evento 389 enviado com sucesso!
# Evento 390 enviado com sucesso!
# Evento 391 enviado com sucesso!
# Evento 392 enviado com sucesso!
# Evento 393 enviado com sucesso!
# Evento 394 enviado com sucesso!
# Evento 395 enviado com sucesso!
# Evento 396 enviado com sucesso!
# Evento 397 enviado com sucesso!
# Evento 398 enviado com sucesso!
# Evento 399 enviado com sucesso!
# Evento 400 enviado com sucesso!
# Evento 401 enviado com sucesso!
# Evento 402 enviado com sucesso!
# Evento 403 enviado com sucesso!
# Evento 404 enviado com sucesso!
# Evento 405 enviado com sucesso!
# Evento 406 enviado com sucesso!
# Evento 407 enviado com sucesso!
# Evento 408 enviado com sucesso!
# Evento 409 enviado com sucesso!
# Evento 410 enviado com sucesso!
# Evento 411 enviado com sucesso!
# Evento 412 enviado com sucesso!
# Evento 413 enviado com sucesso!
# Evento 414 enviado com sucesso!
# Evento 415 enviado com sucesso!
# Evento 416 enviado com sucesso!
# Evento 417 enviado com sucesso!
# Evento 418 enviado com sucesso!
# Evento 419 enviado com sucesso!
# Evento 420 enviado com sucesso!
# Evento 421 enviado com sucesso!
# Evento 422 enviado com sucesso!
# Evento 423 enviado com sucesso!
# Evento 424 enviado com sucesso!
# Evento 425 enviado com sucesso!
# Evento 426 enviado com sucesso!
# Evento 427 enviado com sucesso!
# Evento 428 enviado com sucesso!
# Evento 429 enviado com sucesso!
# Evento 430 enviado com sucesso!
# Evento 431 enviado com sucesso!
# Evento 432 enviado com sucesso!
# Evento 433 enviado com sucesso!
# Evento 434 enviado com sucesso!
# Evento 435 enviado com sucesso!
# Evento 436 enviado com sucesso!
# Evento 437 enviado com sucesso!
# Evento 438 enviado com sucesso!
# Evento 439 enviado com sucesso!
# Evento 440 enviado com sucesso!
# Evento 441 enviado com sucesso!
# Evento 442 enviado com sucesso!
# Evento 443 enviado com sucesso!
# Evento 444 enviado com sucesso!
# Evento 445 enviado com sucesso!
# Evento 446 enviado com sucesso!
# Evento 447 enviado com sucesso!
# Evento 448 enviado com sucesso!
# Evento 449 enviado com sucesso!
# Evento 450 enviado com sucesso!
# Evento 451 enviado com sucesso!
# Evento 452 enviado com sucesso!
# Evento 453 enviado com sucesso!
# Evento 454 enviado com sucesso!
# Evento 455 enviado com sucesso!
# Evento 456 enviado com sucesso!
# Evento 457 enviado com sucesso!
# Evento 458 enviado com sucesso!
# Evento 459 enviado com sucesso!
# Evento 460 enviado com sucesso!
# Evento 461 enviado com sucesso!
# Evento 462 enviado com sucesso!
# Evento 463 enviado com sucesso!
# Evento 464 enviado com sucesso!
# Evento 465 enviado com sucesso!
# Evento 466 enviado com sucesso!
# Evento 467 enviado com sucesso!
# Evento 468 enviado com sucesso!
# Evento 469 enviado com sucesso!
# Evento 470 enviado com sucesso!
# Evento 471 enviado com sucesso!
# Evento 472 enviado com sucesso!
# Evento 473 enviado com sucesso!
# Evento 474 enviado com sucesso!
# Evento 475 enviado com sucesso!
# Evento 476 enviado com sucesso!
# Evento 477 enviado com sucesso!
# Evento 478 enviado com sucesso!
# Evento 479 enviado com sucesso!
# Evento 480 enviado com sucesso!
# Evento 481 enviado com sucesso!
# Evento 482 enviado com sucesso!
# Evento 483 enviado com sucesso!
# Evento 484 enviado com sucesso!
# Evento 485 enviado com sucesso!
# Evento 486 enviado com sucesso!
# Evento 487 enviado com sucesso!
# Evento 488 enviado com sucesso!
# Evento 489 enviado com sucesso!
# Evento 490 enviado com sucesso!
# Evento 491 enviado com sucesso!
# Evento 492 enviado com sucesso!
# Evento 493 enviado com sucesso!
# Evento 494 enviado com sucesso!
# Evento 495 enviado com sucesso!
# Evento 496 enviado com sucesso!
# Evento 497 enviado com sucesso!
# Evento 498 enviado com sucesso!
# Evento 499 enviado com sucesso!
