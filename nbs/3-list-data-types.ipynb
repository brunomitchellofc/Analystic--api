# %%
import requests 
from pprint import pprint
path = "/api/events"
base_url = "http://localhost:8002"
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8002/api/events'

# %%
response = requests.get(endpoint)
print('ok' , response.ok)
if response.ok:
  data = response.json()
  pprint(data)
# Out:
# ok True
# {'count': 7,
#  'results': [{'description': '123', 'id': 7, 'page': '/test+'},
#              {'description': 'Inline test', 'id': 6, 'page': '/test+'},
#              {'description': '123', 'id': 5, 'page': '/test+'},
#              {'description': '123', 'id': 4, 'page': '/test+'},
#              {'description': '123', 'id': 3, 'page': '/test+'},
#              {'description': '123', 'id': 2, 'page': '/test+'},
#              {'description': '', 'id': 1, 'page': '/test+'}]}

# %%
detail_path = "/api/events/6"
detail_endpoint = f"{base_url}{detail_path}"
r = requests.get(detail_endpoint)
print('ok' , r.status_code)
if r.ok:
  data = r.json()
  pprint(data)
# Out:
# ok 200
# {'description': '123', 'id': 6, 'page': '/test+'}
