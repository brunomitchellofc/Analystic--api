# %%
import requests 
from pprint import pprint
path = "/api/events"
base_url = "http://localhost:8002"
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8002/api/events'

# %%
response = requests.get(endpoint, params={'duration': '5 minutes', 'pages': []})
print('ok' , response.ok)
if response.ok:
  data = response.json()
  pprint(data)
# Out:
# ok True
# [{'avg_duration': 96.0,
#   'bucket': '2026-04-20T07:55:00Z',
#   'count': 1,
#   'operating_system': 'Other',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 198.5,
#   'bucket': '2026-04-20T07:55:00Z',
#   'count': 2,
#   'operating_system': 'Other',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 259.0,
#   'bucket': '2026-04-20T07:55:00Z',
#   'count': 1,
#   'operating_system': 'Other',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 204.0,
#   'bucket': '2026-04-20T07:55:00Z',
#   'count': 3,
#   'operating_system': 'Other',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 86.0,
#   'bucket': '2026-04-20T07:55:00Z',
#   'count': 2,
#   'operating_system': 'Other',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 158.0,
#   'bucket': '2026-04-20T07:55:00Z',
#   'count': 2,
#   'operating_system': 'Other',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 155.97530864197532,
#   'bucket': '2026-04-20T08:55:00Z',
#   'count': 81,
#   'operating_system': 'Other',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 159.66666666666666,
#   'bucket': '2026-04-20T08:55:00Z',
#   'count': 75,
#   'operating_system': 'Other',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 160.44578313253012,
#   'bucket': '2026-04-20T08:55:00Z',
#   'count': 83,
#   'operating_system': 'Other',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 149.02083333333334,
#   'bucket': '2026-04-20T08:55:00Z',
#   'count': 96,
#   'operating_system': 'Other',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 153.7173913043478,
#   'bucket': '2026-04-20T08:55:00Z',
#   'count': 92,
#   'operating_system': 'Other',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 141.45679012345678,
#   'bucket': '2026-04-20T08:55:00Z',
#   'count': 81,
#   'operating_system': 'Other',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 150.9655172413793,
#   'bucket': '2026-04-20T08:55:00Z',
#   'count': 87,
#   'operating_system': 'Other',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 165.25,
#   'bucket': '2026-04-20T08:55:00Z',
#   'count': 84,
#   'operating_system': 'Other',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 142.6043956043956,
#   'bucket': '2026-04-20T08:55:00Z',
#   'count': 91,
#   'operating_system': 'Other',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 144.47435897435898,
#   'bucket': '2026-04-20T08:55:00Z',
#   'count': 78,
#   'operating_system': 'Other',
#   'page': '/singup',
#   'ua': ''},
#  {'avg_duration': 126.64285714285714,
#   'bucket': '2026-04-20T09:00:00Z',
#   'count': 14,
#   'operating_system': 'Other',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 140.42857142857142,
#   'bucket': '2026-04-20T09:00:00Z',
#   'count': 14,
#   'operating_system': 'Other',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 158.91666666666666,
#   'bucket': '2026-04-20T09:00:00Z',
#   'count': 12,
#   'operating_system': 'Other',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 143.31578947368422,
#   'bucket': '2026-04-20T09:00:00Z',
#   'count': 19,
#   'operating_system': 'Other',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 143.6153846153846,
#   'bucket': '2026-04-20T09:00:00Z',
#   'count': 13,
#   'operating_system': 'Other',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 157.9047619047619,
#   'bucket': '2026-04-20T09:00:00Z',
#   'count': 21,
#   'operating_system': 'Other',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 153.15384615384616,
#   'bucket': '2026-04-20T09:00:00Z',
#   'count': 13,
#   'operating_system': 'Other',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 143.0,
#   'bucket': '2026-04-20T09:00:00Z',
#   'count': 12,
#   'operating_system': 'Other',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 138.8,
#   'bucket': '2026-04-20T09:00:00Z',
#   'count': 10,
#   'operating_system': 'Other',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 166.92307692307693,
#   'bucket': '2026-04-20T09:00:00Z',
#   'count': 13,
#   'operating_system': 'Other',
#   'page': '/singup',
#   'ua': ''}]

# %%
detail_path = "/api/events/6"
detail_endpoint = f"{base_url}{detail_path}"
r = requests.get(detail_endpoint)
print('ok' , r.status_code)
if r.ok:
  data = r.json()
  pprint(data)
# Out:
# ok 200
# {'duration': '71',
#  'id': 6,
#  'ip_address': '202.224.147.59',
#  'page': '/pricing',
#  'referrer': '',
#  'session_id': '2124f115-c361-47ea-baa4-47147e038ab3',
#  'time': '2026-04-20T08:57:18.726426Z',
#  'user_agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_3) '
#                'AppleWebKit/531.1 (KHTML, like Gecko) Chrome/28.0.812.0 '
#                'Safari/531.1'}
